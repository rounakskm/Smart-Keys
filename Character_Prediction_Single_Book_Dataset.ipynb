# %% [markdown]
# # **Character Prediction Engine**
#
# This is the heart of the smart-keys agent.
#
# Its a LSTM that will take in some representation of the input and return the next character in the sequence.

# %%
# Code to check the resources available Ex. GPU RAM
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/45/99/837428d26b47ebd6b66d6e1b180e98ec4a557767a93a81a02ea9d6242611/GPUtil-1.3.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.6)
# Building wheels for collected packages: gputil
# done
#   Stored in directory: /root/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.3.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 11.3 GB  | Proc size: 141.8 MB
# GPU RAM Free: 8295MB | Used: 3146MB | Util  27% | Total 11441MB

# %% [markdown]
# #STEPS:
#
# Libraries & Dependencies:
# 1. Install PyTorch
# 2. Install any other dependencies/ libraries
# 3. Import all required libraries including PyTorch
#
# Getting, loading and preparing data:
# 4. Get text_corpus file from drive to colab instance
# 5. Read text_corpus file
# 6. Prepare the data from text_corpus file for training and testing
# (Find set of characters in corpus, one-hot encode characters depending on vocabulary etc.)
#
# Create, Train and Validate the model:
# 7. Split the encoded text_corpus into train and validation data
# 8. Create the LSTM model
# 9. Train the data using the training encoded text_corpus
# 10. Validate the model using the validation text_corpus

# %% [markdown]
# ### **Installing required libraries and dependencies**

# %%
# Install pytorch
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision

# %%
#Check install and version
import torch
print(torch.__version__)

# Check cuda avaialability
if torch.cuda.is_available():
   print("Yay!!")
# Out:
# 0.4.0
# Yay!!

# %%
# Installing PyDrive
# !pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.11.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.4)

# %% [markdown]
# ### **Importing required libraries and dependencies**

# %%
# NumPy & Pytorch

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

# %%
# Set_trace is used for debugging
from IPython.core.debugger import set_trace

# %%
# PyDrive
# For importing data-set from Google Drive -> Colab VM 

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ### **Loading text_corpus into the VM**

# %%
fileId = drive.CreateFile({'id': '1stICwWLnHkBeQ60pksTH5IQMgXBmPaAV'}) # id of the file being uploaded
print (fileId['title'])  # outcasts.txt
file = fileId['title']
fileId.GetContentFile(file)  # Save Drive file on Colab VM as a local file
# Out:
# outcasts.txt

# %%
# Check if text_corlus is present in the current working directory
# !ls
# Out:
# adc.json  outcasts.txt	sample_data  text_corpus

# %% [markdown]
# ### **Read text_corpus and prepare for training**

# %%
with open('outcasts.txt', 'r') as f:
    text_corpus = f.read()

# print(len(text_corpus))

# %%
# Set of all unique characters in the corpus, will give us size of vocabulary 
# Will have a-z, A-Z, special characters and numbers present in the text_corpus
characters = set(text_corpus)

print(len(characters))
# Out:
# 79

# %%
# Creating a dictionary with integers as keys and charactes as values
integer_to_character = dict(enumerate(characters))

print(integer_to_character)

# Swapping the keys with the values to create a character to integer mapping
# Characters as keys and integers as values 
character_to_integer = dict()
for index, char in integer_to_character.items():
  character_to_integer[char] = index

print(len(character_to_integer))
# Out:
# {0: 'f', 1: 'P', 2: 'M', 3: '4', 4: 'c', 5: "'", 6: 'j', 7: 'F', 8: 'U', 9: 'y', 10: 'z', 11: 'ô', 12: '"', 13: 'u', 14: 'k', 15: 'a', 16: 'V', 17: 'Y', 18: 'h', 19: '0', 20: 'o', 21: 'e', 22: '_', 23: '6', 24: '7', 25: '9', 26: ',', 27: 'v', 28: '?', 29: ']', 30: 'W', 31: '\n', 32: 'C', 33: 'i', 34: 'B', 35: 'N', 36: '-', 37: 'd', 38: 'r', 39: 'n', 40: 'K', 41: 'D', 42: 'T', 43: 'E', 44: 'H', 45: '2', 46: ':', 47: '5', 48: '.', 49: '[', 50: 'Z', 51: '1', 52: 'J', 53: 'q', 54: 'X', 55: 'l', 56: 'm', 57: '8', 58: 'O', 59: 'w', 60: '3', 61: 'G', 62: 's', 63: 'b', 64: 'I', 65: 'x', 66: 'S', 67: 't', 68: 'A', 69: ';', 70: 'é', 71: 'ï', 72: '!', 73: ' ', 74: 'L', 75: 'R', 76: 'p', 77: 'g', 78: 'Q'}
# 79

# %%
# Encoding the entire text_corpus using the character to integer mapping

text_corpus_encoded = []

for char in text_corpus:
  text_corpus_encoded.append(character_to_integer[char])
  
text_corpus_encoded = np.array(text_corpus_encoded)

# %% [markdown]
# ### **Custom Data-batches for training & testing**
# The goal is to generate batches with features : stream of characters and targets : same stream of characters but shifted by one character sequentially
#
# The input to the data loader is the text_corpus but in encoded form (using character to integer mapping)

# %%
class TextDataLoader:
  def __init__(self, text_corpus_encoded, no_sequences_per_batch, no_of_characters):
    
    
    self.no_sequences = no_sequences_per_batch
    self.no_characters = no_of_characters
    
    self.batch_size = self.no_sequences * self.no_characters
    self.no_of_batches = len(text_corpus_encoded)//self.batch_size
    
    #print(f"No. of Batches generated from given corpus = {self.no_of_batches}")
    
    # remove extra characters, so we get full batches
    self.text_corpus_encoded = text_corpus_encoded[:self.batch_size * self.no_of_batches]
    
    # Arrange data in no_sequence_per_batch rows and rest columns
    self.text_corpus_encoded = self.text_corpus_encoded.reshape((self.no_sequences,-1))
    
  def make_batches(self):
    # Each step is number of characters apart
    for chars in range(0, self.text_corpus_encoded.shape[1], self.no_characters):
      
      features = self.text_corpus_encoded[:, chars:chars+self.no_characters]
      # Array of zeros with shape similar to features
      lables = np.zeros_like(features) 
      
      try:
        lables[:, :-1] = features[:, 1:] 
        lables[:, -1] = self.text_corpus_encoded[:, chars+self.no_characters]
      except IndexError:
        #print("in except")
        lables[:, :-1] = features[:, 1:] 
        lables[:, -1] = self.text_corpus_encoded[:, 0]
      
      yield features, lables
      
    
  
  def __len__(self):
    '''Return size of the data set'''
    return len(self.text_corpus_encoded)
  
  def __getitem__(self, idx):
    pass

# %%
# Testing dataLoader and the generator
T = TextDataLoader(text_corpus_encoded, 128,128)
x,y = next(T.make_batches())
print(x[0])
print("*******")
print(y[0])
# Out:
# [42 44 43 73 58  8 42 32 68 66 42 66 31 31 31 64 31 31 42 18 21 73 44 33
#  77 18 73 66 67 38 21 21 67 73  4 20 39 62 33 62 67 62 73 20  0 73 67 59
#  20 73 38 20 59 62 73 20  0 73 20 39 21 36 62 67 20 38 21  9 21 37 73 18
#  20 27 21 55 62 26 73 62 53 13 21 21 10 21 37 31  4 55 20 62 21 73 20 39
#  21 73 15 77 15 33 39 62 67 73 15 39 20 67 18 21 38 69 73 20 55 37 73 18
#  20 27 21 55 62 73 59 33]
# *******
# [44 43 73 58  8 42 32 68 66 42 66 31 31 31 64 31 31 42 18 21 73 44 33 77
#  18 73 66 67 38 21 21 67 73  4 20 39 62 33 62 67 62 73 20  0 73 67 59 20
#  73 38 20 59 62 73 20  0 73 20 39 21 36 62 67 20 38 21  9 21 37 73 18 20
#  27 21 55 62 26 73 62 53 13 21 21 10 21 37 31  4 55 20 62 21 73 20 39 21
#  73 15 77 15 33 39 62 67 73 15 39 20 67 18 21 38 69 73 20 55 37 73 18 20
#  27 21 55 62 73 59 33 67]

# %% [markdown]
# ### **The LongShortTermMemory Network **

# %%
# LSTM net with 4 LSTM layers, 2 Fully Connected layer and 2 dropout layers
# Each LSTM layer is a LSTM cell that takes hidden state and cell state as input 
# and produces new hidden state and cell state as output

# input_size = Vocabulary size
# Output of the network is also of Vocabulary size

class LSTM(nn.ModuleList): 
  def __init__(self, sequence_length, input_size, hidden_size, batch_size):
    super(LSTM,self).__init__()
    
    # used for live debugging, use next command to move to next line
    # set_trace()
    
    self.sequence_length = sequence_length
    self.input_size = input_size
    self.hidden_size = hidden_size
    self.batch_size = batch_size
    
    # LSTMCell 1
    self.lstm1 = nn.LSTMCell(input_size = self.input_size, 
                             hidden_size = self.hidden_size, 
                             bias = True)
    
    # LSTMCell 2
    self.lstm2 = nn.LSTMCell(input_size = self.hidden_size, 
                             hidden_size = self.hidden_size, 
                             bias = True)
    
    # LSTMCell 3
    self.lstm3 = nn.LSTMCell(input_size = self.hidden_size , 
                             hidden_size = self.hidden_size, 
                             bias = True)
    
    # LSTMCell 4
    self.lstm4 = nn.LSTMCell(input_size = self.hidden_size, 
                             hidden_size = self.hidden_size, 
                             bias = True)
    
    # LSTMCell 5
    self.lstm5 = nn.LSTMCell(input_size = self.hidden_size, 
                             hidden_size = self.hidden_size, 
                             bias = True)
    
    # Dropout Layer 1
    self.drop1 = nn.Dropout(p=0.2)
    
    # Fully-connected Layer, out_features = input_size = vocab_size
    self.fc1 = nn.Linear(in_features = self.hidden_size,
                        out_features = self.hidden_size,
                        bias = True)

    # Dropout Layer 2
    self.drop2 = nn.Dropout(p=0.2)
    
    self.fc2 = nn.Linear(in_features = self.hidden_size,
                        out_features = self.input_size,
                        bias = True)
    
    
  def forward(self,inputs, initial_states):
    '''
    Function responsible for the forward pass through the network
    
    Args:
      inputs         : Tuple of batch, input_size at each timestep t
      initail_states : Tuple of hidden state and cell state, initailly set to 0s
    
    Returns:
      Collection of output sequences at each timestep t
    '''
    
    # More debugguing
    # set_trace()

    # Initialize empty output sequence
    output_sequence = torch.empty((self.sequence_length,
                         self.batch_size,
                         self.input_size))
    
    
    # For every time step in the sequence
    for t in range(self.sequence_length):
      
      
      
      # Passing the input sequentially through all LSTMCells
      initial_hidden_state, initial_cell_state = initial_states
      
      initial_hidden_state.requires_grad_()
      initial_hidden_state.cuda()
      
      initial_cell_state.requires_grad_()
      initial_cell_state.cuda()
      
      state1 = self.lstm1(inputs[t], (initial_hidden_state, initial_cell_state))
      hidden_state1, cell_state1 = state1
      
      state2 = self.lstm2(hidden_state1, (initial_hidden_state, initial_cell_state))
      hidden_state2, cell_state2 = state2
      
      '''
      state3 = self.lstm3(hidden_state2, (initial_hidden_state, initial_cell_state))
      hidden_state3, cell_state3 = state3
      
      state4 = self.lstm4(hidden_state3, (initial_hidden_state, initial_cell_state))
      hidden_state4, cell_state4 = state4
      
      state5 = self.lstm5(hidden_state3, (initial_hidden_state, initial_cell_state))
      hidden_state5, cell_state5 = state5
      '''
      
      # Passing output of LSTMCells through dropout and fc layers
      output = self.fc1(self.drop1(hidden_state2))
      
      # add final output to output sequence
      #output_sequence[t] = self.fc2(self.drop2(output))
      output_sequence[t] = self.fc2(output)
      
    # returning output sequence
    return output_sequence.view((self.sequence_length * self.batch_size, -1))
  
  def initialize_hidden_and_cell_states(self):
    # The hidden and cell state at the start are all zeros
    return (torch.zeros(self.batch_size, self.hidden_size, device=device),
            torch.zeros(self.batch_size, self.hidden_size, device=device))

# %%
# Setting the device that will be used for training.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# Creating the model and load it into the GPU
model = LSTM(sequence_length=128, 
             input_size=len(character_to_integer), 
             hidden_size=512, 
             batch_size=128)
model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3af0f9d4b897> in <module>()
# ----> 1 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#       2 print(device)
#       3
#       4 # Creating the model and load it into the GPU
#       5 model = LSTM(sequence_length=128,
#
# NameError: name 'torch' is not defined

# %%
# One-Hot encoding a tensor
def to_categorical(input_instance, num_classes):
  """
  Function responsible for one-hot encoding a given tensor
  
  Args:
    input_instance : np.ndarray which is one instance of input that is to 
                     be one-hot encoded
    num_classes    : total no. of classes
  """
  return np.eye(num_classes, dtype='uint8')[input_instance]

# %% [markdown]
# ### **Optimizer & Loss function**

# %%
# Using Adam as Optimizer and CrossEntropyLoss as the loss function

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.01)

# %% [markdown]
# ### **Training & Validating**

# %%
# Separating validation and training set from the encoded text corpus
# First 90% data used for training and last 10% data used for validation

validation_index = int(len(text_corpus_encoded) *(1-0.1))

validation_set = text_corpus_encoded[validation_index:]
training_set = text_corpus_encoded[:validation_index]

# %%
def predict_next_char(model, input_char, sequence_length = 128):
  
  model.eval # set model to eval mode
  
  # Set initail hidden and cell state to 0, but now batch size is 1
  initial_hidden_and_cell_state = (torch.zeros(1, model.hidden_size, device = device),
                                      torch.zeros(1, model.hidden_size, device = device))
  
  
  # placeholder for the generated text
  seq = np.empty(sequence_length+1)
  seq[0] = character_to_integer[input_char]
  
  # Encode the input character, (1, input_size)
  input_char = torch.from_numpy(to_categorical(character_to_integer[input_char], 
                                               num_classes=model.input_size))
  input_char = input_char.float()
  
  input_char.requires_grad_()
  input_char = input_char.to(device)
  
  # Add fake dimension, as input to network needs to be batches
  input_char = input_char.unsqueeze(0)
  
  # Forward pass, without dropout layers 
  for t in range(sequence_length):
    out = model.lstm1(input_char, initial_hidden_and_cell_state)
    hidden1, cell1 = out
    
    out = model.lstm2(hidden1, initial_hidden_and_cell_state)
    hidden2, cell2 = out


    out = model.lstm3(hidden2, initial_hidden_and_cell_state)
    hidden3, cell3 = out

    out = model.lstm4(hidden3, initial_hidden_and_cell_state)
    hidden4, cell4 = out

    # Passing output of LSTMCells through fc layers
    out = model.fc1(hidden4)

    out = model.fc2(out)

    # Applying softmax, to get probabilities
    out = F.softmax(out, dim=1)
    
    # Out is now a vector of (1, input_size)
    # Get top 5 best predictions based on softmax probabilities
    prob,top_characters = out.topk(5)
    
    top_characters =top_characters.to("cpu")
    prob =prob.to("cpu")
                                      
    top_characters = top_characters.squeeze().numpy()
    prob = prob.detach().squeeze().numpy()


    
    char = np.random.choice(top_characters, p = prob/prob.sum())

    # append the character to the output sequence
    seq[t+1] = char

    # prepare the character to be fed to the next LSTM cell
    char = to_categorical(char, num_classes=model.input_size)
    char = torch.from_numpy(char).unsqueeze(0)
    
    # Type conversion before feeding the new char into LSTM
    #input_char = char.byte()
    input_char = char.float()
    #input_char.requires_grad_()
    input_char = input_char.to(device)
    
  return seq

# %%
# empty list to store model output
model_output_list = []

# Training the model
for epoch in range(50):
  
  # Initialize hidden and cell state to zero at the beginning
  hidden_and_cell_state = model.initialize_hidden_and_cell_states()
  
  
  # Creating instance of dataloader class
  T = TextDataLoader(training_set, 128,128)
  
  # To find average loss per epoch
  batch_count = 0
  loss_sum = 0
  
  for i, (feature, label) in enumerate(T.make_batches()):
    
    # One-hot encode inputs, convert into tensor and transpose them
    feature = torch.from_numpy(to_categorical(feature, num_classes=model.input_size).transpose([1, 0, 2]))
    # Converting input to FloatTensor
    feature = feature.float()
    
    # Transpose labels and convert into LongTensor
    label = torch.from_numpy(label.T).type(torch.LongTensor)
    
    # Wrap features and labels in PyTorch Variable
    feature, label = Variable(feature),Variable(label)
    
    # Convert features and labels to type torch.cuda and load them into the GPU
    feature.requires_grad_()
    feature = feature.to(device)
   
    #label.requires_grad_()
    #label = feature.to(device)
    
    optimizer.zero_grad() # Makes sure the gradients are initially zero
    
    out = model(feature, hidden_and_cell_state) # Forward pass
    
    loss = criterion(out,label.contiguous().view(128*128)) # Computing loss
    
    loss.backward() # Back-Prop the loss / Backward Pass

    optimizer.step() # Update the gradients
    
    # Validating every 10 epochs
    if i%10 == 0:
        # Initialize hidden and cell state to zero at the beginning
        hidden_and_cell_state = model.initialize_hidden_and_cell_states()

        # Creating instance of dataloader class
        V = TextDataLoader(validation_set, 128,128)

        for i, (val_feature, val_label) in enumerate(V.make_batches()):

          # One-hot encode inputs, convert into tensor and transpose them
          val_feature = torch.from_numpy(to_categorical(val_feature, num_classes=model.input_size).transpose([1, 0, 2]))
          # Converting input to FloatTensor
          val_feature = val_feature.float()
          val_feature.requires_grad_()
          val_feature = val_feature.to(device)

          # Transpose labels and convert into LongTensor
          val_label = torch.from_numpy(val_label.T).type(torch.LongTensor)

          val_out = model(val_feature, hidden_and_cell_state) # Forward pass

          loss = criterion(val_out,val_label.contiguous().view(128*128)) # Computing loss

          model_output_list.append(''.join([integer_to_character[k] for k in predict_next_char(model, 'A', sequence_length = 1024)]))

        print(f'Model output for epoch {epoch+1} :')
        print(model_output_list[epoch])

    print(f'Batch : {i+1} Loss : {loss}')
    
    loss_sum +=loss
    batch_count +=1

  print(f'Epoch : {epoch+1} Average Loss : {loss_sum/batch_count}')

# %%
print(model_output_list[-1])
# Out:
# Aa issasi sitsitaa sa its  sss   aisa  s s ai aisiassttstata  tatat isstisitstttitsaaiaaatsaitatattaa ts  i tt atatt a aiia s tats attiit i  aa asa ss t a  t  istiatii  iitaiis aia aiaatata   it tsstiasatiaiit atasia  iii  sst  st aa  aat iiii ttits  attatst saiattttt si aa   asti assi t t iai   ti tiistaiit i   t astss i isa aiasiai sisasattastts tt aaaa statatasistiasitts i itasiiit saaat iast i a tis  atsi  sts ttiai issta   ii  tsatasttsaassttai is    ats ii   atssstaisa asaatsatsststs ttts   ai t tt  ita ita tsassaststisaiiaia ia  sts   ttsstatstastais t isst ss  aaa ata sttts is a aaaai isita atsatiaastisa  itit ai sta ss sttasisas iaat atta tsiii tstaitiit s ttst  sita tsasi a  ss tt t ats sitt ts ittiitat ataiasaa saitst ti  a isa istit iaii i s saistttai a iissttsisias i iaitissss  s  tta a aistiaistias  s at    stts a i sstat sttsa s t stitt tti ati ti st a  sa  ss  i  a t ttt i tt itiaaisissaa attt iaa asaa tas  s iitiit t  itsitist s saaaaiti tttst   aiia   sist i  t ati i tass  aa  t at tit  ttiis

# %% [markdown]
# ### **Saving model data to google drive and fetching it for future use**

# %%
# Saving the model
torch.save(model.state_dict(), 'model_data_initial_state_100.pt')

# Check size of model state dictionary
# !ls -l
# Out:
# total 41700
# -rw-r--r-- 1 root root     2578 Nov 23 18:02 adc.json
# -rw-r--r-- 1 root root 39744985 Nov 24 03:03 model_data_initial_state_100.pt
# drwxr-xr-x 2 root root     4096 Nov 20 18:17 sample_data
# -rw-r--r-- 1 root root  2943701 Nov 23 18:02 text_corpus

# %%
# Upload to drive and work with it
from google.colab import files
files.download('model_data_initial_state_100.pt')

# %%
# Fetching the model_data file from google drive
fileId = drive.CreateFile({'id': ''}) # id of model_data file
file = fileId['title']
fileId.GetContentFile(file)  # Save Drive file as a local file

# %%
# Creating a model and Loading the state data saved earlier

# model = LSTM(sequence_length=128, 
#             input_size=len(character_to_integer), 
#             hidden_size=512, 
#             batch_size=128).to(device) # If running on GPU

model = LSTM(sequence_length=128, 
             input_size=len(character_to_integer), 
             hidden_size=512, 
             batch_size=128) # if running on CPU

model.load_state_dict(torch.load('model_data.pt'))

# %% [markdown]
# ### **Validating the model on the validation data set**

# %%
# Validation loop
model.eval()

for epoch in range(10):
  
  # Initialize hidden and cell state to zero at the beginning
  hidden_and_cell_state = model.initialize_hidden_and_cell_states()
   
  # Creating instance of dataloader class
  T = TextDataLoader(validation_set, 128,128)

  for i, (feature, label) in enumerate(T.make_batches()):
    
    # One-hot encode inputs, convert into tensor and transpose them
    feature = torch.from_numpy(to_categorical(feature, num_classes=model.input_size).transpose([1, 0, 2]))
    # Converting input to FloatTensor
    feature = feature.float()
    feature.requires_grad_()
    feature = feature.to(device)
    
    # Transpose labels and convert into LongTensor
    label = torch.from_numpy(label.T).type(torch.LongTensor)
       
    out = model(feature, hidden_and_cell_state) # Forward pass
    
    loss = criterion(out,label.contiguous().view(128*128)) # Computing loss
    
    print(f'Batch : {i+1} Loss : {loss}')

  print(f'Epoch : {epoch+1} Loss : {loss}')
# Out:
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 1 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 2 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 3 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 4 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 5 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 6 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 7 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 8 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 9 Loss : 2.555915117263794
# No. of Batches generated from given corpus = 1
# in except
# Batch : 1 Loss : 2.555915117263794
# Epoch : 10 Loss : 2.555915117263794

# %% [markdown]
# Validation loop achieves loss values similar to that of a converged network

# %% [markdown]
# ### **Predict output**

# %%
# Testing on smaller sequence length
seq = predict_next_char(model, 'A', sequence_length = 128)

# Convert sequence elements type to int, 
# else we wont be able to use them as keys for integer_to_character dictionary 
seq = seq.astype(int)
print(seq)
# Out:
# [71 69  3 69 31 31 57 48 31  3 57 48 69 31 48 31 69 31 57 31 48  3 69 31
#  48 48 57 31 69 57 48 48 31 69 48 48 48 31 57 31 48 48 31 31 31 57  3 48
#  69 69  3 31 48 57 57 31 69 31 57 48  3 48 69 31 57 69 57  3 69  3  3 31
#  57 48 57 69 31 48 31 31  3 48 31  3 48 57 48 31  3 31 57  3 69 48  3 31
#   3  3 48 48 48 57  3 69 31  3  3 48 57 69 31 57 69 31 57 57  3 69  3 48
#  69  3 31  3 31  3 69 69 57]

# %%
character_sequence = [integer_to_character[i] for i in seq]
print(character_sequence)
# Out:
# ['A', 'o', 's', 'o', 'a', 'a', ' ', 't', 'a', 's', ' ', 't', 'o', 'a', 't', 'a', 'o', 'a', ' ', 'a', 't', 's', 'o', 'a', 't', 't', ' ', 'a', 'o', ' ', 't', 't', 'a', 'o', 't', 't', 't', 'a', ' ', 'a', 't', 't', 'a', 'a', 'a', ' ', 's', 't', 'o', 'o', 's', 'a', 't', ' ', ' ', 'a', 'o', 'a', ' ', 't', 's', 't', 'o', 'a', ' ', 'o', ' ', 's', 'o', 's', 's', 'a', ' ', 't', ' ', 'o', 'a', 't', 'a', 'a', 's', 't', 'a', 's', 't', ' ', 't', 'a', 's', 'a', ' ', 's', 'o', 't', 's', 'a', 's', 's', 't', 't', 't', ' ', 's', 'o', 'a', 's', 's', 't', ' ', 'o', 'a', ' ', 'o', 'a', ' ', ' ', 's', 'o', 's', 't', 'o', 's', 'a', 's', 'a', 's', 'o', 'o', ' ']

# %%
res = ''.join(character_sequence)
print(res)
# Out:
# Aosoaa tas toataoa atsoatt ao ttaottta attaaa stoosat  aoa tstoa o sossa t oataastast tasa sotsassttt soasst oa oa  sostosasasoo

# %% [markdown]
# ### **Make the model write stuff from a seed character**

# %%
# Run model on validation data and see what model writes
# Starting seed is a
model.eval()

# empty list to store model output
model_output_list = []

for epoch in range(50):
  
  # Initialize hidden and cell state to zero at the beginning
  hidden_and_cell_state = model.initialize_hidden_and_cell_states()
   
  # Creating instance of dataloader class
  T = TextDataLoader(validation_set, 128,128)

  for i, (feature, label) in enumerate(T.make_batches()):
    
    # One-hot encode inputs, convert into tensor and transpose them
    feature = torch.from_numpy(to_categorical(feature, num_classes=model.input_size).transpose([1, 0, 2]))
    # Converting input to FloatTensor
    feature = feature.float()
    feature.requires_grad_()
    feature = feature.to(device)
    
    # Transpose labels and convert into LongTensor
    label = torch.from_numpy(label.T).type(torch.LongTensor)
       
    out = model(feature, hidden_and_cell_state) # Forward pass
    
    loss = criterion(out,label.contiguous().view(128*128)) # Computing loss
    
    model_output_list.append(''.join([integer_to_character[k] for k in predict_next_char(model, 'A', sequence_length = 1024)]))

  print(f'Model output for epoch {epoch+1} :')
  print(model_output_list[epoch])
# Out:
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 1 :
# Aaaos ts oataastast  stat saot sssaaota  os soott tsottaatsa  ot  tsasts osstsotsooattttao t otstsoo otoooto aotatooaaoat satttsssaootaaaao aoassotssasa ooaa sttoattasto tota oo aoat aas taotoaoaooatosaaoatassastt ttat astastoa asatasttaooosaos  o oootoootat ttaso tttsaoassoos  sattsst aostotatsaatsoss o s ttststsaos saas taaoastto tsss otaosoaaoos atossttatoooooosoa aasa at  at taaso tossoo   o atto oot ot stas  sst so ta assattt staotoao otastas ott oasstostso ts tots too  tasooaattassoooto  to otsttos oaossta oott tsota o o  soaoat  tatoo   s sttstasottssstotooo ooo ao aat ssotoa a ttttaas  otsoaoo ssostta attts taaataa  ss s o tstoooott o oao taotttoss   oasoa ttst sossao a otas ot  ssa  aoaaa t a oao  o tasostoaos  oaassoo taaot t ootas s o  aootsasaotaoassttata asaatstto o a ta oaos o  aataooot saataaa a attsaa tattaotota ass ss  to taoss ss    tso tttt stoto a  aa ao ssossatsasttaoootaaao  ts  otatoto  t ssstotooostasttooots astos aasstssattsoas t tsoo asso atsotaasaas os sttosaoaso ttaao sstt sottotsot
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 2 :
# A  sostos aasooatos saoatt o   soas at sot    oatstoaa aat ta osoosa staa st stttaatao taoasotaoosssotto a aossas t st  sstsaaa ost ttastsastos  aaototssaotttssaoasoaastt sassssstossas aassootot  s  a osasaaaastooa oots oaot oto   otoo s t tta aosaota ttot  t sata s totsos oo oaostatt saatoat  sasoa s sssooaaotto  atasoaottoaass soaoatat saaat  astotstaatststtotstosstts asoass so aaaa t  ott aotttot osos  sstooaaosa ottsatots aoaa stt ataaat saastota t ottattsssaaaassstottatt satttsos sa t  toa  a ottotst tost aats asaasttttttssassootootstoat tostaaotsaso t a sssosttooaotta ooao o  sotsstoso  oso sooaa saos os a osttot saaatttosaoottttasottoaaotttt saosoa sa totatttao  tst to tssaoa o ss att ta   asts sot aoostaoatao t sooasa osttto t a s saatstt  sassa  taoosst at s  a t oo  tsts aastoto tatostsaasoao aaa ottaosta oattostaaoooaaotosaos s stas atotso  taao    aaa stsststaato soosoat tatosaaasooataooaasoo astsssasttat st tttsast a  toataa saaotasaoa  sasat  ssttotottttss o a  tasooas  ts o  ttaatstss stt osttto
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 3 :
# Asota  aa st oosts o tst aat ot    oa soo   s ot ooatsaa ts atata aaaosattaooatoo ttaatao ttsooaaaoototottoo ostaotottsttts o toa ttatt attoo soososoaasass ooo t  s  ta sossstttoo osos sto ttttt ta oataoasastosats oasatooattt s ssoaso stt otasottttstoso tooaoa  ttstoaaatso aoaa ta so ttatt asoot atasaaat t s taa ata asaats totstossttooasts otaa oottataaa aaottt ot astt ssattstt tsosss sastta  ttssattsa tstoo staoaoso aasa otaaotta aattaass tts aotaso ttosatst at tatsooaottstttt aotoo a ossaaossaoattaoaatso  toat at aooa o taaaaatstatts ttot ssoatt ootso tasaaasst  ttsa s tastt  toaats toaot oattatt  ttattsatttsaotas oataaaa   asotato tatast  tsso attaoat aao s o   tatsost  aotot satst  aa o  oota o t osos ss   oasat stotssst o taosattatoaos ttoo ta aot atoootstttootsao ssost ototaotoaaaoostttao   aotot a taa   totost aattostta stsaoat ot tsotsootot   aattasoto at aoa s ataottasoass aaa tstsa st ta tsoa  taot a  attosas ostaos o ao taoo ooaata sastsasaoot aatsotssaaaassoatosssaaoaaaoto ttaaoaaot s ao t tos osot
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 4 :
# Ao ttsooats taosaattstaotsssottaoaoa tss  sosttsao to oasattatato oaaasaaaa saa satotot  at osttstssatt otsoot a tsos oaaatotas s astoa asa t  t atassottttaso  saaa oaotto ttot otottotaaaoooaaotsto oaaastto a  ttoassso  saoto tot aasosst a t a  t oos t oaas aaoss sttssssso ataototas   o tasaostottt ttoootaaaosttattaat aoaa os t aoaost aat ttsttsast ostto tot o oosts a sttaaatottossooassa  otttta  ts  tooassttoos sssaasaaoa ssot a tooaa o t  so taaao st  oot a   s ts  oo tattaaaosatoaso  statts  tso ta osaottaaasaoao tato aoststttotttasaatstast ao t tsaatoo tta os oootts otoatoatt  oa sot  oa ta   atotsssooaoto otstt toaattoastota aoa a ttaooa to a  atast a ootsaoastsoaaoooa  aaoooaatstsaaaaa atatosat sasota    t  otaos  tsatttsat t atot ot atossaoaa  so tas   oa  ostos tatsa  o ooaaat sosastots   soaatt oasa t aoso  atsa a oosaststs oaao otaas oaooto ta attsotos stot ot tttatsaaast  o tttotosaoaasttast  aa ts atsos a  asaoattoastotostotsatt ot oaos oo aa asaoaao asoao sa   s oata so s ttaotoaaoas otos stos oa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 5 :
# As t tt tsottaa totota s tataaass soosss tsat s taataastsotsoataoo ta ssaoattat osssta otao ao o stssssaataoo oats o a t ttaaaoottaat o sttt a aaatat statts ss o ots oosstoso   assaoas t  aastosaaatosasa ot a aaoo aoasa o   ttooo otosasstt sosatsss a ssots s  sosoootttsa  stst  a tttosaotsa t osaatt ssasa st as  taoaaa ass aao aootsota   soto tttt s aooatto a at att aotttsost  tosta a oo saso sooa  tt ts satto tssaotsta ttasassoao otaoootaoooaototsas  ososo o taoas a t as sttttotts a ooootatttststsa aoststtotottaosto a aasa astt tsos  otostatoat a tast ottta ooa tatssotasta tstootot  so ott sstatto o  a t sosstaososat saao asss  saostaastattsaoossas aots  tooos s aoatsstst toat ooatsstoaso  at tssotss  tt tsttato otso stata  atatt ao atttasaas assotttoss  sata  oos o aa t oaaaasttatstot staoottt otss a sassoattaa oto osttoastot st otao aot aaatoaotss otststaottasatasoatao tt tasoat os sttooooaootta taoas sotaastoato  ots ooooata a a osoo oattos otststtttooaaasoa aaaoas oosaoo atsaaaa tstoaoaas tsoastsoaaatato
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 6 :
# As tstaatt attssasa ototosaaatttssaaaoa sassost atstaassatoottosststaosstatoossstto stsastsstoo ot aat saa assato ssttsttosootst so  sotaaotoott oatastoaasaaootss saotsa aotttt t so tss  toa aata  tssataaoosta tos    ooastst ttaaaaoa t os  ao t ootottossasatttsas aaataaaooassa   aa  aosotaooaatoo astssataao t saaaatasts ssaootstatatotasaassooott sos oot ooott ato atstta  ottt oaos   otasattt  osa ststasaas  oa saaaossoto o ttt s soosssaootsattsaa tao  ostos ssooo att tat sot o taasaaa taa tssstaa saaosststatatsotatsstooooo o t aa t sotottatt toaa  ooatt saat atsttsoao a   otatoa osttt o oo asa a ststasas osoaoo asaoota ossasa  soso oaa  t ata ata ata st t s  tato to aoo t tstasa tato  stsaat oot o attataa a sotatsao sssts taossst saaa o s oosottso sstaat ostoootat asstaaoa ao sotoo  sta sasa sotaa oaooo  aaa o oo a t as taaataaatsoaaa taoaaatossasaa oosstatasaso oottaosstts ts t ot ttst sas  aoatt oo totot s oatot ostta at oosttsaoas ooostaotattsa a aootosattttssooststst otaottt  tos s s oaat at ooa taooo  sot
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 7 :
# Aaottsoaso ssasttta t tsas tttoaaosa taa saaat ttoat taa ot toaoa   aassta ooao aooatssst tstsoatsatotaottotaasataostataoasttot ssootoott atttoosao ts atotoootooat ttoaaastoaa ottottttat saaasaoottatttt a  ossao t tss   oaaaoaaat tt atsstaatttossoaas t tssoassa  soaaass  totosassttatsoatts s s  aaoa aaoot   oo at s aatt  stooaoso saoatta t oa t tasao to tssoott soa a oosaotooo t   taoastt saosat ootttoa tasa   atssaaot ttooo toasoott  st osaas saoaaatao ao a oooost sta a oto ts otaootssattsstttosa  totsssaosott atoaatotatttot astt a  t s  stas sssostootsa ttotoasotattttssotato o   ato  ttottos t a    taasssaso assoo aaatt    staattsotat otts atttosatsao o tssso o ato aaatattaattas aotaasaatattatoa aastssaatasa aassaasa aotosaotttat sssootaaastsssot atto sootooaaoatt saottooa ttso ttatoottt tsa atta tsso tootoaoo tooaaaa tasso ttssa  ot  otasttaasaaats ssstt attastootattstoaa atsoo  otatta totsaaa ss  a sssto tt osa sa stassoto ooataatttaaaa  t stt a ta attotatotssstaootas  o  sso sasa sssso taatta tat sssataso
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 8 :
# Aossaooatt a ato oatt a ooo tstoaotos t s satataaaasasoao ataos astsatst  at ttsss sttotaaa  to  t oa   oot aot  ostasaoatasatssasta   o ass  aastotattas ta tt tototato at asta tatttasaa oao taoaoa oa totsoa  t  osts   os attt o  st  tata oa soa saaatoa otas atoatoaoa  toaoott sao s  aastassatsttsattos asstataasatat tt aa tso oaas tosso toso tttaoatt oo aotoott  sotstt asta ats taast   to s sa oo otatoass t otostaststottsaa ttatsasost oas taostso at ta sooa  ttaostotoosa toaotst tastaaata  sotttttsaasos tostasta atsttt aaat  to aoas a sasasts tostas asaatt atast  o t tt ssoo atsss taatoa  soaata sooos a oaataa ssa asst tttatoaosata staso taoaoto tos ssttao toosasasosossootatattts stotaataat  tsss oattotosoa  t  sstosa tss aasta so assssoaot ss sttoatsao tsaoattssaastoaooaot o asoasos attotasto oa  atott sattoo sas aaastt a aaatts  sasstatttooaoa t t saoo sots ttasas tat oao oaasostto oota saosstt tss otao sataoso at aaaaooo aoaato oa assssatssaao tsaoatoa oa sststatt oottsasoo aso oo aa ooaot tattatosatatss  t
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 9 :
# At ttsta oa  tsoa  asossstts toso otasaattt   oaaatossota at ttasts aata  st toottssooo tsoat otoaoo atos taatso aao ssaaatosaoooat  aaatt s atssaotttst too otstt oo os  oos ao asoaoaotstoasaastaa  sotsootasas ast asa  t tso tta ts s asata osttatstao totosts o  at asa  aasso  oaaaaata oa sooatssso at tto t satott  osososs  a  asata tttot tsasao tooa s  ooatssota oaaassaasoosoosaoaoaaa at ot oosa as ot asotasastot ssots sto tattasssso aatt  taatt tstato so sttt taoa ttaoasat oa o taao osoas  tasosaaastatats tasst  ataasaa  tsssa  staaosasat aastsats osaaoaoaoott  t    atsataosotta s ttaa tooa t ostssoo oao osts otao oa  stt oooo otosstaaaoaosssootssastttttttoata toas o oaaoaa s a sssos t  to to atatttot  ta sss a tttstatoasosattatstaasott   sasoa oost oo  tttoatoosastasottot ttts saaosooo tttto at toasotss asoo ts s  sot tsasososots  tss sttoaoooa osatsaaoootassossaot tosot t stt  otosststst oa taasaas   atotoat toot sstatas saaoooaoostosoootassto stsoato atsaa tatsatotsasastast sososa tsaa statooa  o soo s ot
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 10 :
# At t tttsoaaaooosassotasaoosss as   oassaaasa  osaosoaatttooaooatastsataoaa  at os osaosaossssa as ast at s  tssoso sas   ts   aat tts oaaototstaosaa tsoosst ta oot oosatstsattataaaataao asa o  taass t s so a taot asosaaaasota  stotsots  attatta stoto aoosootasst soo taa  aa totattasas tass atsotsto o t aoassooaot tssoasoossttsotastootoooattsossoot  t so st o  sottott t  tsao  asssaotstsaaasttooota  sttaoa saaaaaa   os tsast  asaotatooaa  ttaa  ato stso ossa aoas osstasttaot otasoss as aoss o tt sa oo aats sto  a tssaotstso s  ss s s aa sao ts ao ottt asas  aott toao stoaa oa otsao  s aoso sso t taastt att stassooa tssaaasottaasaaaatos  aos t  staotttoao aasatss a soaasoo aottao so ot tssosoo ttatoot a aa  o  os atsoottsss t tat ttt  otsasso tttoot   s saosstto totstsaataoaostoo oatt asasoooatttatosststtatssssao oo o  oaoaaat  aoat tsoat  ataotassatots  o soastsoooaotat  s tat tstaattto tts taattssstaaaoosatst o ssao aatosta ssts at oaa stto toato sssasaoos aossass  ostataatsasa asoaotosoaa tossttottoaoaattstt
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 11 :
# Atttsosotsoot tatsoassattotaoastaaoa   o ototstaaaso osttotato aataoototo oaas   ooastsoa tsasoostta oa  oaasa taoaos aatttsstsot as o aaaoss toa t o  osoo tast ssoatast oaatasss aoosao otoso  staaa sttt aatottaotoast tsts t s a  aass oo oaaoot sat oottat asa ot ttts oo t aaasoaatoataas as  as ottatooss  s t ts ttso s a ootoosssaot otsa  tasttottttatot ast a aotaoooas tto  ota oot  tttatt oaa oasoasaasotsosst  osttto    staooaattssoaaaoattstaotsotsooaasastosttoaos taattoto otassttstast sat t osaoass totts oaa soa    ooaaastaaost ssssoaaos sa s too tot oa  ott oaa sasa   toaa ooot o ao ta stat tatataoa os oo taoaaatsa as  a  tsttta taa too a s o aotssta soaasoo oaat s  s aosasatota oa  stoost o a soa taaotatosao  assts tassttossa ots otstoo ooooattoto oaoo tasttoattsso ttsa sss  st  tstaasooato oosaats osassatso sso os  sasastttst s t   aasoasatsttatts tts assoaoaostaosoot tata stsaotasa s as s t toatt asotatasaots t otottttaoststataastoa stsasotasa aot  osoaottoo  taa ooaastosasosotsoa  tts ao taaooo ooassatao
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 12 :
# Aaso a tos   otsaataaas ota ta tot tttato otooatssto osatooa   aaatoatooatooo  oo a   oo  astt otasasooot ta sa tstataooa ott osaoooattaaata sttttasaa  ttsta  soaa sso a   tsts  stsa a tosaaaotsaasosot oaasttttostao ooattos atsttsaso ot to toat  a  s astsosas a aoststat  otooaatttaoatattas taoaoatoss ssostotatsaa aattaatttosataattaa ts a ttoa oaststooaostt o tts   ottsasttasotssostaoso  t tato  taotsassaaaotoastaaaossatassaostoo sas oatt ts  tsottatots as saotoottast ataataaa oas a  saaosoattotaasaossa atoa aaot otaaatsoasootttast  o otattttaoo att stosttassoa  s  attt  stsot t  oatta tastt ostsatatt tttasotssst tao a otsaaotsaoatsatsttsstsoaaassatotoots ass at ossasootat t ts a s as  assooaotooottt t  taastsaotssaotttassosast aoaos sssao tst  asoata  o a ossstatstsootos osatttso ost ot toaa oat  o  sttoottssaa sttotas saa ttotostota  oaaaaaastosa ttaaa ttto asooooota tooots oatootsttaat tt oatsoao  otttoososaaoaa astasstooo sso otoaaaots s t ostatootsasa aaotaat tt tst s taoott oa ooatsttsta t stt  ato oaasss
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 13 :
# A s t as t aaaoota aa ot  totota so     t  tostaotssaooaota s asoa so  ooast s s a  atoaoos oststta a t  oatostasataat  atooassaoaootaasot a  asttt oaaoaatos tasot tt aoossaasssostsotso as s oassssasoata tstt ss sts s sssasssaaoa atst ssattaotttat  oot sto    tt stoo s  ooosto s aoo toaoa tta sststsootots atsottaaa   t ssoasataosaatasoastaot aoootaatosta  saaaatttaoatt tst aaat t oaoataaotas satsaaataaaa tss s taottsaataoa sost ttsaotastsosootsto ssoooasasao oa osoas   ttst tosossost t  totsoa sasas  t ttaaos      sososaos   atta atst  oaaootst totasta saasa ootataoattoa t s stao t otsot ststtsato sooat ta oooosotoatst sassass ao so  t toossotaossastosoootosoatataaottsoaaoato oottaaoo ooso ao ssoostaaaot  stsaoas osstotaaa s  a sstsooa tooaatotaata ooatt to    asts tsaaoaastssa oss asstsaaaa s  to aaaos tstoatossat  toaottto   asaostoot tssta ttttoaoootoso ots sato a tatoo  toatttsta t ts sato as t sso o otttoa taoaottoost tttsat ststt oat so s o saa    attsstats oaasosataasatstsa ttttssattoato ststsataa asoat
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 14 :
# Assooso too too o sa oooatotsssassaasotoaa tsat toa ta t osaaaototaatatatso st ttotooos aoto totst oata ssostoaatas sssttsoataa aoao stsosstttoatatttoosttaossttttas oaattto   tatotatoooaa ootas a taosatastooa a a totoao  oaoos tss aoaottot ata oa a taaaattattaotsas oass a ataa toasat aatatt tos a aat otoatata otto ss a  aaaaao  aatao ots  aoaos taatoatoaatoo ta a sot  tsa   tsoasos a aata sottsststoots tt atao  soa osas otass tt tto aooasotoosttsooatostso taotsttoostaa asootsao oatts aaooos ts ts stt oat taasoatooatsta to oa ot aaatootaotaaootaoasa taaooasotaaasssaoaao ttat   ts s oot   staasaaot  oossa assao oast sst o aoasosst oatststat staaao stssas t oaaoaaoaas tttso tos too t oatsotsso tattaaootta taoo s tt tostotoatssasaataottaooasa aaas attsotoaooas oaaaottsatssttosoaastoaossao a  tao aaoost  tttt at  tt t sostoaosoao ts os toas s sstasastoass soaa sato oso a tst toosst tossosaaoaaatt aatot  stoo  oo oat st osoatttotosssaaotat stt tassaatstao tasassttssoo a oosttt o   ost ttssoa tststs  aosootatoatasott
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 15 :
# A  o  aotta sat ssstso attsataaa sst  ttattoa s to oaoooosaatoo satatataaa ttatssa  t oo s  aatsoto tts ttoottstaao   ootsssotsotaotasaoostsaaaooooaaa at aato tst otoaot tatatssta tasattoa  ast ttsso  aat o ooaaaoootatostooo oa otat aotaottt tssa otootsta as  a tssa sa  o sss ootataasaa osaa osa oo  asoaotsaas ootsastsota tsoat a t ottooaaasttsaoa os toootssaa ost  s soatst tsa astta ataotsttss t aataaatssst otasaa  aa   a ot to otaaaa   sstsoootsaatao staa o sosoastaata assto  ats t toaasssoaotssat tsat   ttstoaotat a ssotottosootooao ssosostts  saatass sato  oootaoaoaoaoooas aaoasso saoa tstaoos saoao asoo ot ta ototsaot ao  sst aoos a osaoaaoatssts t ota aoso taat ot tstotostso ss astsaatt asata tsttatot  t sottaatatosottsostst to a tta aaostt sstsas  t ttooaat astssoosoatottotssototts stoaoos sasstatt oasassoott oaa sttattaaaotoo  tsa osoasoasotttotaoos ta aatsss st o aa s tta o o oosoooaaaa t  aso otsasats     at oosttotssaa  s att sosas ooosttsos   taossaaaoa tstoattaa tsoaootas ta aoat tsstassta tato ta
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 16 :
# Asatt to ttt  oaatos atoaotaasoasotoa  tsst sosoa s  oasottoooaoosttoasa  otsa  asosa ssoaotato   ao sottttotoa a a t satttso ttst  at osoaattttt  o t ata toto  tats asottsas tat osatoaatssssat ososaoaooasosa ats saasoo oat ttaoa aaaoassattasostoooa oat oo asatasooottaooaassoaooosta oa ts  s taotttaoss  aaotoaass taatsttossta stt osss so sotsttaotsotaot  tstsatota o osooaosao  tts a  ttsa o stota sooossoostos ooaa tataasaaotsats s  saaaotsoa oa o   taaoaa oataas sa sooo ttstoatassasaaoassot oo  oaso  otassttaaa   oossosoas a tost  aotts aa ssaoostatoa a a toats a s aatstsoaaa s aas as a   ssossataos  at   t toaa  t  toos t ootattstota ta s ssosaos o  asos  sotoo  oooot s   a sst tasto tas as atoos sottttsosa aoasat sattassats oott ttttatototsttas otaos sasaossso a toa a stotota tsaoatosstt os ttoat oat otstaa  oaa atstt  osotto tos s tattassoosta otaootss tat sstsosoatso  osssoattsaoatt  oaoott ostsoaotot s o saoasa ao t  o sosoo aaa ato tosast osa ttaasoat attototttsooo ooot ss  a ostosotaaataotttastot tsssos
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 17 :
# At a t a oaas ssta tta tttsoottssotottaotastta  ss otaso ostatatt aot  asototst tsso  tooattsss asos t sssto  taa  ss  asottssasoaas tsttstoa s o staaaastattat soa ssaotooaoo ots ttsastotstsato toastoa sa saotsoatssaa o staa ooss sttstastoosso aato o atoo aa ss oa tasst oaotatta asot taattooottosao ttttss tt stoo osta t ao  tso oasotstta ta tsa ostt oaaaatsas o asattt sso soss atas oatoatoaos ataat toaaot oaaoaoosaaoatt taaooosoatoaat ts tta otasoatss t st stasoaao  ottsoatoaaataostott ottatoossssoats s attstosta aasaata o tt  aoso tototoss as s tosooattsosaosootatta  oo sota t saaat astsotsootsttos a asssaoaost t taststttaaa oatttotatoo sostsoooa o ttosttttat a  oss  ootsatstaoto aa  atao  aaa t otoaoaoooot ottt ttoao ast  ts ott    aotas sattst tt aotstsoot s   toso tto s tots sotossstot sastat  otosstt saso  a tat oo t ttstatao a ast oasaooa at s ooo tosotaa sso a  tta t toostaoasosataaoo  stsatsaoss taa  o  s os taa oasa so ssstooas oo aoasaa stao sta  sosta  ta  o aatoaasaooaotsootaaasststo aaasootottasas
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 18 :
# Aattattottoa aaooaso sst    s otsto t tttsaa taoa  t ttt  ttaoastsatstttsstots aaotsa soasatoo s  tassotatos tatt ottossoataotsoooastt oaa oa sotosstt a stss aatostsstasa toatt  tottst satoastot saastttsottst osssttoaoa toast oatttststtao astttttaottat ttttttoooo tttsaa  sts tt aoatttaoooto ao asasooaasotta tsaooot tt sstt osa  t sattsoosss aastt tto  stts ost stttos aottaoatotottotstasatt sttatso tat aoaotatstotttatatata  ss  otst ttoasssattat  aasssot a taoastasot attaotstotts  a tosttootttsotaostaatas o t t tost otootatasttatasaa tosttoaotttattoaa oaosaooao  ststs  s tssa s otosta  ostaa totasosas sttasataasaos taat saoataaasottostas ossa ss ttta sssosaasasto sttatsstas asoot ss oas s  s ssoaoototatstoa astst sasstaott stoosostotoat  tss a tt   s oo ttso tstsaaoot o aaaa stss    o oosas oaoossaso aoatoatost soat tos  toat stastsooaoo a oatot stoats a  ooasot  ossotoaoaaoa oaso a tata aottassotoooooaat sttsttasta sto ooasosto ts tsota  o st oosatstoso tsaa saotootototasttos tottots oas aot  tooooao oattoastt
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 19 :
# Aotsataooosttt t osoa tsotoaatatstattot osotaso stsstoaso oaoattoatttos attssotot atssaaota  saaa aottst o atsast o  saaasttoassaaasos oo t ot tas oo  aos tttaosaosa tta t so ott aatssta t  tott sssa ttat a otat ooosts astttsta tttao ssts ooss soa aaatstaaott saosatoaoats aa  ssoosaasosstosaa ttatost aotssa so aat aa oooa ts sstooaos ts  tasoos soa satatossoat sasaos  totttsootsstaass tssstatstooso atosoo sa soaats  sa s oasoootttsstso taaa a osotttstsa ototattatotatts otsstotosaoaastsasssasosa osatsaso o os  ttasts staaoo a asta  at oo  t aa tso astootot atsttttatooaotot tsssa tst st o asot  sto ttsotoaoos toots t  ssaotssooatot tsssaot toso aoot  oos stoss tooaa  toaa saosa ao  att assss  atatoaot sotstsss ta soooaooo tta atostossooo soasostat totaa os oss  s at ao sssos o tosoaat o  taastoosaa   asssast aatstttata  totoaa ooosotastoatooot  tts ot att  attoottosas attso oottta ssss stot ooa aatas ao ttoasotsooos  oottat otat stattotat ssts aaasoa   a oss toootttoasatta ssstttattaaa staoooso as at oso asaaat
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 20 :
# Aosass stttsttaoatstaoaos  asst  oa  o oao tstotoooaossto sttasttt asttt s aasssta otttttssatssotaso stttoataosootatosot  aatttsa tostso atstso ato aot  ootoooaaosts astoaotsoaaato oasso stt os stasaoataaasttstto otsta sttosasataotsta aootottotassaasoasas toosattssaotosoooo o aoata tsststsat a atostaso ottoa tootss ssta aaaasassot o soo  as atsooat a aao ss  atsttatasaaa o s ososs aattaas stoaaaoottsa  a oats  oa aa ootttao aaosaoatt a   a at ta oaat ooats ost o saa a ss statoaotosoostotta ttoos  oso aosoato  aotstattat ts sstsoss aaooatttsa totssaotttao toott oo soas saatota asao  tsaaa asaoo atosat aottooo s tasstto taao   otta tt tso oaoaoos tttotso sasoossssssoottato atato at tasttotas at ooa tttat aaa saatatsoo soss a oaoao a sttaasoaaa o  tsatstastotaatottoosoaatttaoaotsssot tss  aoost ta t s oaatsaoas stssotta asaot  saatsoooat a sttsttt ossss aa atao asoao aoaasoaototsa tao so stoasotsatotao oa oo ttaoaaa  atatto t tttassosaa saaatso aatao stsatsossaoasstataaoasoaaoo tt ottaa  ttoaoaatat tstaossso soos
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 21 :
# Asasaot sttotots oas ss o so atstaoat ttaattaosaoaast ot ssttt o totooatts ttot o  ta    oa tst  s soasaostsatttsaasaasattaoo atoaosassat sosaatoota atsatoatoaats a t t sssotottot  ooas t toto s a  ssattootoaoso t  st tatattotoast sst otataoatsootstastostss   sotsattas tttotstoot tata satoao a as osotat  tottttaaas o ao to oa a tssooaaotassatosass tt at tstsoatoosa   oootaotaao ssa  o aao taata ats tssassaass soato  st ao aaoaoat tossa tassst ta a   as o ss atootosoooaaaatsssoaattaotaotatosssooootatooatttsato ostssaa o tottattaa ot t aaooao to ttssaot taatooosst  ttsoatat ostttstttattatsto aottsoos s asststostssta t ttstatoaastsstssoaa oootsoaoooo taa oooaa atsoata   ost s  sa   t t tsa aatatss s ttaatsatoossa  toaossasa ssssoattts aa osa aastotaata  osoasa  ttat tsotaoaosot  at tas s atao otoaoastotststoos tos saot soasoottt  aaoaotot aa   otostaosats tssto sot saoaoaaaats ossaa statoa ttstssaaa otatassa s asatsatttttotosaoasttoastas tto stto o sso a otosooataot  osaattatsastaotas tssaotottsosatattaottasoosto
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 22 :
# Aa stota ottaassoso stsottss ottstosttos tto asattattao  atsaasaastaasst  otaaaaao  oaosaso to att stooosoooaosaatt ao  ootooosattasassso tst tsota  tsaaot oaasstots  o sssottsooa osoott  aatasaosatostssttt atsast atattsaaaotosttstttttooa t ottot ttaoao aaototo ts tts oatsa ottato tttsa  oa otaa aat toaosoaataa s aa toasta asts sssaa t a ssta tsaastotossas ota tttottto st  s s tsoataos aaao tott s  ooo sssstss  tssstaa o ot atastattotso aaooto o t oato s ostasotstoaastasoo   tt t  tt ssatatssot st tttaa too ataaatoostoaaao  taao s ss  otottssssostsot aaoooaosta  tttt sststsssosoatost asaoo oaossot tt atttoosoattato oaosaotas oaoaaostttttaoasto sa aoo stattosoo aoaaatttatas ass oss tao s ttastttata aasss so aoo sa s sasaotaaatttstoo tts saa tso aotoa asataa saaattt aastsooaaasso aat a sossss a tost satsto tooaaotsao ostas  ototttaottot  aosstas satssostss  t ata tas tttattat stosata   toaaoa t sott sto ssssa t s os  a taot aatsos so attss  ttaost sasttts saas osaotatottatoaatassatato osts sotts oaot  oosotaattt
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 23 :
# Aa statss sasat attsaaaoa t tsttt o   oo taaat otasotot astsa oo atao  o taatt s atts soot o ot aas s toasoos ootaasao ostt ttosoo    aso staa aaoa ooast soo sao aaat ota sto t oaato tsoaa t aattot aotsattt sat  tso tssssasat  sttt taaa aootaotsoo tst sas assoaa asasaatso s ts  sot o tttto ts aaaastttt  ttt tt oaaatt otat ts tooasats osstsoso o  ao aaat taotat aaotooattaotsass  saataos    sts asttta aaoooaot    oooo  attsasott t st aaaoosoo tsaat ts aootssaa oao o  aaooosstossotatta a oattsoostat tttootsaaaaats oss oasa otto  t sa  taaatot  sotsotaotatsa s tsasat asaotao atoa   o oaassst sttttto o oastootasa atoaa s ooot  oatttstotsatoastt ss  aosottttooats t o tta aoststoa s oaats tsoasaa a aotat aaoo taatsoaaatsotao asatt tt s astot to ao ottsa otssastsssoo aotatsa   ata t ssaoo attaas sotoa tt aosaaotttst s a assas ta aotstaoa osat  aoasta soot ssas aaotoostssatoaost  tosassssos tttsaaostattaa sa oat osa aooaos sott  soassttsoasost t tt     a ototso ttsstototoaos   saostoaostaa asstoatossoatooss taaso sttaa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 24 :
# Assssttsstss oas osatatot tat at soa ssoottots a too ostoaotstoosatstaot a as tasostaatssaatssot   ststtt atoasttoaoaos  oost sso totttosa a  t ootoas sotttsota otssaossstoato aassastoaaatsott a  sat ssasss   as  sosto att  ao sotoaaostaataat  ooo oaaotsostasastaao   toat oaasta osass  ttat oa t ttoassta soaootoataaat sa o saootssa at oatas tttasotsattaootst  taaa toosostts so  otsa asst tsoaoo aaoa  ssstaottoaoao t tsotaaota ts atatosssostssootttts sottstt   s asota tsto o s s tt ssaotaos tttttts sotoasattt a oas aotsto s  tot s ootot o  aaas  aaaoostastats tosaos sooso  aa oaoosaso ota  oaoasaas ta oatsoa sstotoatattaa osot    tots satatao toa a oaos a sso a  sto aat o t tostos sattso   otssso ts a ooatsaaoott  attos ao o sott tatooato s osatt aassasasooatosaat o taoa    tsostaa s ta  o saot sottottaa stotosaottotsts tt tsat stoatsttao attooatstssaaoo oso oasaaa taat o aaost ooa staataa tatots ooaaattaos sataaoaaoaso atta  aoosoa aoatassoas  o tastats  s  oaso saoaattoossssoassaasaao otaaot oasaaoo to aato t
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 25 :
# Aasaotsstsaoaaso sts sa  oott tssooat ooa asst sat s tat s  o  to    aa statatstostaattast as s otsoos st ottsaooat  ottato ta   ttas ootoostt sotts s totsottoootaoosataaaatttot aoo tsatss a oassaa aaososststsssata  t as so oata ts a   sats  tts sattaotao tstatootsaaaa s stasosa to sostooasstttstotsttt ssa taa ttasatataats osa   ta st o stootstatts  otosss asatsaast tsta otostt  oa oattts soa ttstotssatao ta a saao ts s s  sootoaaoo so tsaooso tsaaatttots stoa  ttoaas ttaootasos s   otsts st atsooaaoaasat  a aooa s sottaoosstt toaas  oo  ssts sotsso t  st tass  sa  aatossts oaoa otssasossasoooaaatatssoososots tts oaottasstossaaao ts stt soo tats toaaotasaootooa  st t  sto stttoosttsos ooa o oat to sssootot oaaa tstaa  aaaa o as ost at aa ta tas ass ottsosttt stt o t ossssot sttaatoos  toasossso aatstsataaoat  ttoa tosa  otaottsts aotoassaotosoot aaaso ttot tsat ootas sao  a toatoosststotoat saasttsto o oo s sattots  aoso otootatstaaasoaoo  tasott ooo aststotoos  o stot toat aasatto  tstoaaastaataoooasssa taaot
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 26 :
# As s a toataaooao  sat so sooossoasaasaaaa s sa otsoot  aotot   ta taa asaso  tsss aot t t aststssotasta attosas  a sos   saosso  s oosatootat oo  attsa satosaat soatta  s tsato a saott oao tst sata  o osatooasttasssaos  o tasssaattsao sao taostttattta ooa sataasaosaas t t sattaootassa saatstttoaatsstt totsaoooo aaoos   otsts aatssoatao o asoasatoasooasoaot sastassaootas sssaaataaaaoataao ass ts  ooao ttosot toa asotas t   o ossoo  saoas aaa at a tosasostas ato atasastsasotoaat osos o  oasattotaaas sa oaoasos aot  t os tastasoa aa aaoatastots sa   a tssto ao to osoto a ttsst toso s attoss  ot tooaoaat oats sa s t aaot taa t tosss sat o as otsatsot  ttaos o aaaoas ssasasastsotoototttaasoaaat   tsa sss ttoasstaa a ttosatsotsoasosa as a ssatsots asaa aassattsostaaa oss sa asass ots s  oattts  tsataasst oatoo sassttss saats tsao  ss ttttsaaasasass aatssstaottaatta soattoa  aoattasas tt t  a totts  sstott s osaasossottsaoata tot saasosat tst o tt as   toa as oo  ossssasttt os tosotsototsst soa attttaoaaatas otao  s
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 27 :
# A tottsosstotatosaota satasot    s a t otoaos a toaosattootaotooasaaooaat asota tooss ttost s tats aaotaa s aotso aootttts oso t tos otaaso tssa  aata tsotstosotos tssatataasts oast t a aa ostaa oata toso  t  saosas  ooaa t stss aastas o  s ot at s tto tttsa ttaoo aoaaatosaotsos sssaooos tssattsttt saaat tsa  as  sasto taaossoosta aotttatttaaooastotoas  toassossottoata  to  o tos sasotttaaotsaao a stsattaa ttaottt stsatsaattt t  s toasassstaossaoo aoot  as atsssstott sto sasostt ta osto atot s ttoassss  otststao s  tasot so tsasssstto a o aot ttat ssato  oo atta  as ot as oas o soa o  st attsta a oa tosatoast aot soaaos stta  aossata tsst  s tatta   soaoa taao  assaoss osoa o tttttoa ttaaaos  sttaaotoaosos sat  a sootoottto ssoss sotsotaooaat oss os  a   tta sosoao to   oaatassotta oaa   t  sta aasoao tttaattast  sto ot  os sassosasaaoattot oostaotosaastttootsta tastatt t ototsosaaa ttto o to t a aoaoas   saost ttotas satst   aato osos ooooss tsatootootaattoso tssaot sa s s st  ssaoo  s stsa aao  ottosao astst
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 28 :
# Aao  saosta  osstastsosost  os totssssoot aaasttaoaaoto o a  too aaoottot ta aoss  ttt s atsoo astoooto  o osa  so atottaosttosas otaosot to o aato ss o tt stsa toasoooatt saaoastto s a  t  t asot aaaatoaaaaaaaatsostaoo ao astottt sssststtoast aasots satastassooots stoottaotsaastoaaottooottt tt sa s atoao so sta ao oasoaasoaoossotosottossts  ssatatso oa stass tossta otaoa  ttot osstaoaaas assosoatstsst ts atoaoo aotsao ota ooa  tta sotootatsasso oooa tao otoot astotoao as    aa aasaotsso  ota ss  to oosoootooa  t  oao   oaaat to s oasaoos st ao ts t  tat sototao  aso t oaa  ossssaoststsa taa  o  ssaoataatotaooaosaatsa t satoaoo tosto tstsoasaatsta ttsttoo  aot ao s to aoootstotato o oa osaoottt osaosoooot aa tsoos tt a tataattttoa ot  sao sta asatstatott osstosa tsottsstostostaaosto astt s  ao  taoaa   oaasa ottaatottsoatssaoottstot stsossataostotsa a statot attatt taastots ttosattaootttaa oaoasatatsotoatss   sso a tt t ssaot ot tsa oasoatssttaaosta ossaatoo oattsaa ato oot osaoaototosaos sto ssa t tttoats  o
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 29 :
# Aa aaaaastaaoato tsosos asoo ottotatta  toaooos  o otaaaost o tottsso  ast ta  o a a sasssa aststsasaotstootts stttataaatt tt sa sa ataot o ta totssasosats ssatss ss a  stttsa tso a  stsotssstss stsaoaato tstootttso a  o  aoaaaoa a s assata ttoo a  saoaaoto aooosa oa oos sssotssta oo aoaatatas st aoasa    osoaatt  taattasa  s attttottsotatsost aotts aooo ts t  t tttaatt  sa oas  asosttsattosoo  attostsaa  saatto otst  otttostsata oatssaao aot s sa oto ss soat so sasaaoatotsa asss   ttsstoaoso osttotatassoa stas tsaa oosaa a  oto  ootaastatstaaaooa sottassaasotso t sso oao at atstato otaosa oaaotssooosots  taaaaaoaas tas o oa tta osaosottot ataooooa aoaattaoo ota t o sotsos ts st stoa tsao sooos  tosto osooosoasaaaassoasoaaa taotstoao sstaooasao  oaa  ooos a aaa stoaaoatostassaoa t  stosttaa a aatota    aotos otsttattttotatooo aa tato t tatta  o asttso ot soasasot sosato atsoo sostta ao tttsstoatttto osasttoatstsoossaot oo s taotoos tsa a  o as a sttt ttso  sssota  aoaststttt aaot aasoaatos  soaatttsaaaatatsoa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 30 :
# Asstoasaatatsaas ta ossooaaotatas   ao stat sass  stataos  tt oa s atta aosstoasttoattostss s a at otottst otaststoss   tsaooaotatost tosas t taassassa  osaaoasatataasaassso o s  o ostssoaoaooosoa ata  tott stsa aottost oasaastttts  ta stotstaas  oa oooot saatotsaost s   oat os sotatas ao  to osotostsaotaa at sott sasattoatosotosata  otaoao s atastoa assotosatss  sttaoststt ots o a saooosaataa   aotssat too asssatataot o a ta aasoostotasoat  tota satoototsto t  taoasoottoassstt sooo attaoastao ossat tata  ssaatosost o  st osttsotaoot a otaa  toaaao aoaaatt oo asat  aasss tsst tt s tt   ts tstto  att sts s   sao o atotttoasootoao otsa atat tttatao tttst at  aaaoatoatatt  stoao tastsoatoostoottastssat tst sooo oss ttat  t  tosatosattt  ottssaotost tt o t oooaoaattst ao  saaataaaa s  tosasoatotsas s as ootttt   ooaaatostaasaosotsatstoast osoaoatsstoo tatt sosts ta  aoaatasa s oasoaoa tasssoa  otstt tosss aoo ttaot ostast saa osostota stoats ostosttt atsotoooosat asssoosst so taost  ts atass aasassstostottttst t a
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 31 :
# Assstssosa oaaa oosoos att ss o soaatoatotoo oaott  oat osoots toaaaotototsaaaa sat t  t  s ototosato aaataosts asott  tssoasoasoaooast o otsosto  tsao ss o aaasasaaototsta   t oassstottssa  tasoa oao stotasaao soaoto asasoaooaaoattssaaatso t otsott s  otstta  ttosts stsatstttsoot sato at t stosaotaosoaatasttotstso statta aa asa oassttooto    osassaot ataoo  tt osstotaassasao  taossats aaat taasaso ss too ts  osaatsst astsoo  o oostoaa saotsto atas aa s tttaosta  as aatt  ast otottaaa tssotaatstoataao   totttaoass oaoaaasttso tta taosootsaatoosaott as a  sttaasa tts oosotsatoasaostsaos  oso tast a  t osts o o att t os otttssasss   sta    stot  tooto satoott  atats tststossotooaao asa tato sssootttsoaooot att stt ao stsaatstttttoaatsaot  tootstst aa aosotoaaassosostato to taaasaa stooooot aatosa otoaotaos tttss toatoao  ot a att    tt osatataatosaataottotstsots oaoo soastosooaaosa ot   ss t saot o satsooo atsos tsa  oto a  tt soaosoaoatt oost aas tattsoosttoossttosaosasattsoatsoas ataosttatoastotsst s   atotats
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 32 :
# Aoo taaaoo osso a att oao atooosatataoa aotatoatsatao  aatoast ostso ottsa otaataaaaaootstssaatoo ttsotatttso  t ot soooott tttsao ttatss  tssoasasaoaao aooatos aoo stssottosa taa soatsot s tsastotatstsoa sot  a t asos atsst sooo ottsaaotts t a stootosttooastaaots to s asoa aatstts oos ttoaao t ao tsosttatttotsso aotaoaoooo tas tat attootooaaoaaotoooatstt oaoa  t s oa tatooos sa ostts aoa t atotaotasaaoooatossto  staaot  a saosaoo t oaasaa  saasooa soosttao saoat ottstosststatts saas as stttsa sasaoto aotosaasttaototttao   ooa   t   o attao o otatottoaossts tatottsta oas ott  oaaoooa st sa  a ot  totasstottt aost taot so aosssat  tsossa a stttsstottst saaata  taa o  atsssotosaatts aattsasatsssat at ssaasottaoaatt  astoatsto satatss os osaosostsa tssta oaasootoao toos oa tsaataoastoottaaot aa   asttsatst t  sos soaa taoaoosstsass os tattaaottattst  aaaaa  tt  at  oo otatao ta aososasatooaao  tts a oao atat a atat saoootsasstts taotottaoaooatst so   tsoaa  t s soas  oata  tttsst ttsaasasastotto a  tsa tttaoaoooo
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 33 :
# Ats tssatooao ttoto tsaaaa otsastoaaoao sa tt   ssasaa a osoo t a tsttattoast  totattssosottta sa  asooat oattoasast ttotttt ssstsosto  ooaat taoosts osotstoots aostt atatat ss  atotoso  aas ttoassas  tassstoaa a   oatat  aa oaaos sttatoataaa st  aooasattata t stsa ttotaao taataaa so sssoosssssoototsasota a tt sttao a o o  otss s t toassostssstts s aoasaotsossoatosao   otasooootsa ot ssasasot otoas taostaaoaoaao  taaso otsaaoso tssoto aas soaoaasoototatattaaasttsttttst ao s tosaaoo a sttataa ttoaost oats  sssatssa osttoo taatto sattoaootto satstattt tstsa oas atsootastsotst otso toot aotatt  otttsoaot t sot osoastats t st sta stat totaoatt otostas tattsott otota as  saoossoo s sstos tsos oaootatssaa aotsossstta a otoo tsaotasttossaatoatotaa aoaos  sta to as tsaat satts sa  stots aasa aoaaott tsss ttstt saaass oatoa so aoo ttoo s  ttsostaa toasoo  toaastoooos stt aasatso aoao tstttaootst tattosto o ssstoatoo ott  tat assoats   oasaasstssaaotastaos ata taso saotooatso ota  oasosososaototsosstsot tao ooa s oattos
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 34 :
# Attss  as a tt  ttostot aostsasootsatoooasosat aa a ottoo  astst ota tsoa as ttaoatas atoottastt ttosaaoooo oattaaos to s t o ao asaot as sststoaooo t totatttooooaoasa taos a ttsaaotstt a ao oa ao  soa  saoataotsaata aooa  oatsooss astt soa a o soostsas  ttootat   sttsottootss aa  aaos aoaosso tsastaoaaasoos a aaoototo otosass oss sot sta ssttoaos a a  toototatoas   tstattoaao oo stttaaotaooaosaoasstttt asatoos ttootss ssoootsassso oaost tsttsaoaotta t  ot tsao at a  ost  o  ats sst aattsossottssosaas aosttsass  ao ttoas    ot  tt totoo st osoaaatstsatotstattao tat toat aaottasoaa ass ssotoat a tots aaa ta at o tataa   a tso saaa tsaa oats tsoootsotaas tt otsss aooo s aao oastosoo tto aaaooosaststs so o aa  sototoots osssa ssttat attoo ttt oostss a at t t  sots  ot tattoaaso to aoosaa taaoaoatoo atatassststa ttattooosaao aat saosaas  to oa sot tt  taaaoot o att   ts ooa o oaooaasattoaos oaoa ts saott attt s ottta s totasto soso aoaa atststattts to aaoaot aatasos tsssaat ottttooassaootstst tosttottaasatas so o
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 35 :
# Aato a oo a s t  asosootssa tastssaattto ats sstttaaoatooottsoasaoasas  at ta s aootstatao assaasasstaoto a ttaaasss ootaatoatos aat s  oss  assasosttsooaoosoottaosota sotstaa tatasassstosaast  ooataato a  sot t aot tosa taosta  aoota oatsaasstaso t tt a  ataossast totoa ostaosssaao attooatatassootooss  otttsaastotsaa  tassttatao otosoots o t tttoo  toatsatttatot otoostsao aooastaaa oaatsot  aosa atast otsotsosass ao osso tstot osoataaaoo o  ot oosaostoo ts sstttotatt stoatt ss taaaassaat otstoasoooosto taaoa oo oaaa s  aatttttsaaatto   sosssstssaostasa o  a a s t staas atttto oat s  stsoa taoosoososaoatoto ta to ttotoo aatasoatoat tasass  a tat ttstoo stss saa tatatoaoooaaaaao ootsooaa o ss ttt tsstoa asta a sasa sotataoo tst  o asotaa attooaaoaoa ostas s oaaa a ooststsoasass a s toa ss o sss ss tooos o ttt osttss  ssas aoaooatsttts tt  tasaao a saassssoaootsoootoo soaas  aa soto ottaassaa s  att    oaassaatsttsota ttatatssatsoto toootott stoottt a oootaa so aaoosta ootsotsssaaosattat sas ttoaattato osossasts
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 36 :
# Atsoat saaasosatsaatoato oostsaoaa otsootooaao s ttstt t aatt o o  ttssatstata sotso o taoasaota ootsooaaosto sata oaats aaoaast tttto assstt tto aasao  s tsoasaooottottaaostttttsst   ooastoaosossoaoaaaotaottaattoso assossssaoao o  tos osaa aa  tstsaas  oaa ossttoao ta t  os aooata o aostta taaossatass tatssosasatttsat a taoa ostoas so asa o ass oosoooottoa ao tsooaost  s tttt sttt aostt aoatsoaoatatsa tt aat tta totoao  tattsaaaaa t aoosot aosoossa atat oto ssata   sttt  assoasta aosttsostsa osototsa aasattta ooosstooa   totaaoa osta tt ta oaaaoasoto atosaootostass tt oaasootatatasattat ssootaast ssaa sstaoao  astaaaooo  tsoo taooaatt o  tottsaa tatoaaa  s  aosssooasoaa ttsatttta sstaaosst satta aaso at o  tsstosassstsss sa  aoasttto aaos satsaoossssta oass s satt a soaoaa tt tosstsaststtoasaataaot  tttso sssosatoatotstt at sttoottaatottasaostas os  ss t so otsssoaot ottsosa ttsstotao tstt aaa aooaosaatoaso tstt oa ta ooo ta a tsa a oto t s sttastootsaoaa t stosssass taas ttsoaao ooso tatsoaootsttaaaoto ott s
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 37 :
# Ats   oosaosoa astoo a o s aaasso tto taoa tsoaotto  to  aotsso ttsotsa  ttao ttosaoaatsasstot a ostao ot stoaao  ot aoo a a o aa  aa sasstao oao ostotaaotoso  aooa tsstso aooo t aast oaaa sta osoaosaosoas  toossoatosotoatoo sssaaoasott  sts  to aos ssoto  aastoo stao  atttt  staoost saoaaott s ao taassoaotta  a ooso  a t atoaotottattto a asaa saat atsaasooaotsasoa aoaass otstotta  tatstts sao   t tt ot ssts tatssastt asaoo to  osoaa aotssaa  astosssstastaa as o ostoaotaooss oaaatott tt   s tso t sosttaoatattsosatt ta saatoasoaaooatstaatotottttaot aoss   toas  ssosaooasaaataao ataao t sto  assaosastoaaos taosa o as  t t ott s aoo atatst saostsoo ssotoo st  o to ot t to  ao ttsot  at aatstttotooataooasasoo    ssttott  ttotatotatotttosttaossotoassaattsoaaaa  otttttoatttssotota s ttos taso ts a sssasoo sstoatssat  toooo stt toss soasssssttts  aa tt ats as ats  taott  aaotostsa ssttsoos osooao t oa asaa  asststa a  a  oooas oaooooottasototao  st a atts ooatsa oaaaa attsststot asa os ttaaoaosatt   ss sts so ta tt s
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 38 :
# Atossosatsssstattaatooo o aa  ooosoa ttstastaoo otto ssstsstt taassoat  t ttost otaao aas sttaat s s tootssao  t aao ao ss att osaosssssaottt ossataa o to taosst ao  assatoaoassoaa s o s taoststs t oas ttt   a     too st saaaaaosaoaatasoto tato  oo   taaas atst sooattsso ot ttao tatatsoooa ooooso t ostsaotoa oaaot asoattsts a otoaa aaa ata sassooo  st stt o tsatso ttooataotaaaaatoa  ooaooasst aoooa atostaoo o a aa a ta  otoso t  t st aaosasstaoaaoaa oas aotsasss s sts tsst ssoatot ossoao atssooosaoa ao  ta   at  astsoaoatosota tso a aas aoooaaaottaoooossastattotaa oattastatssttaataaootta a asosaao at oao astooa to ast tat atoaaa aao otaas  ssoaos s toa ost   ot tttssaasata saoa ossasso aosttttasaootos o taottstosatttatotost tts aatot atsatoosaossata sattts  ostoaotatast t tstoattsataot   aaaootaoott aaa sattsatss osstooa sssato tta assosasssotsos t  too  tassatsstttt aotts ssst asttaasto aotattota aaaa  tasa a tttt  aososoo  as oass so oooto ssstastotot saaostto  oa ttt stoa tasa ts to  att t    taoaoo aotaas
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 39 :
# Aaao  s aasaa oo ato a atoo a t osss s osaassttsaa oasasso  aaaaos ttoo   sts ttastst sts aass o taatoot oa t asstoa tstttsato toosoat  oststst  aatsoo   aottotaoosa toosot aot  s oaoaoatatottatsosoast   aos  ttsatsstsosttot aaottt a sat o  otssassooooootatssst ttoastasssatsata tto stsaaot oot o tsaos osstost aotsasstst aotasstt osot tsato tsttst oo ao tat ot taotatasat ttao  oattott oos o totsta aoot to osst  a  taotsttttost atst t soata t asoaassa atttaoosasoaaas oato taat   a atstosasasootstot tttsao soa o a   otaa osototostaaaattatot  asttttto aoasostassootsaa at  st t oss aa tsaoao  oatatts ttotsat assaat ota t    o aat aaoooos aaaatot tosottsoo os attsoa  taost aaoosta oaatasasst aa osaoaa oooa sossa aa ottto o sstsatsoasota s asssa  oooas aa tt toao st asasa stsoattsoaso aasatsssssassso aassa ao ttta os otstostostaassts  stsaattaat   sa ast  ao tst tas t  at saasososatao tasosatt otatasotaoat ssto stotsttt soattaso aooasoa aatoatoot o taatsoot   t  ooossata tsa tsas aa a aaa ssossastttooaott o aossa t
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 40 :
# Asso tasotssata aaa a ostatoatoaooaoaatao aootaaotoa ssa at  tt tt o o t at a ataotsoattat tsos atao soosaas toosoot ttsa as aots aatosaatosatttt stastsaaaooaosttoata toaat ssaastatooa tosa ot oas sos tsstt oasoastoaastsotoaoassa asoatsot t tsasat tasoo   tt  ttoaoosast to  aot aaso as  a aaasasost  a oa toaasots tatotts tssooaota  ttstottta sta  tssoosaaat tat tottts atoo  oaosotto aa  ottt o  otst oattttooststo ao o osso aototoosttaaa osao a t  aaott  sa t ss tt s totss assotssottaasa tasa atatsas aaooa ta aass o  aaottosaaoo a a otoaa  a atotaooa sa aastaasatatssta at   ot sttastas t sosato atosttt  taotsat aoosoa sasottasaa  satoo as a sosoa stst os a saosttastaasaoo tssatstttasaotto ttaoasasa a ttaotaaos ssso ssosatos ttattosaastoaaaaao ta tat  tt stttstastoto oo  tt ooato ao tsttto stto taatsotso stotsotaa  atotatstasossss   ssosotsao  tat ssottoataoooot  aotattsatoot  t  t ssst ataaaottoa at  otstatttata as osooaa o    st t taa tataototososas saaotta  at aaoto o aso ot  aos s a  asasots assstaat st staa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 41 :
# Atoaaa ttat s oastasaoaa ottstt sa  sostaoatt totoa ttatsataotoo aatosaa o ttoosa  s a sto  oaat aa o aasoas ooasasos aasao atoatotoostaoaootoat   at  saat ooaaoasostoo aaaoaoattatasaso o s aast o a tsotaotoaaossasotatotot sssootot taatataaata stsaos too sstatotatataasa as o so aassstssotoot tatoaaoaaattatstooaosass ssas satssaa   otts atst  tt ssso  sa osa  stootsottoaao ssatoa t t toaoo a tta atasst saosotattaoaossttsatass ass  sttaaat  asoos st satoasto aoa ooa ataaatoo a oaaaat tatoat toao a  sata at  a ts osoasaaso taatat aasaatasata asstsoasotsatotasttttsat stsooaotstsassoa ooa oat  osaassto ttt stoosatotsatataossa tt s asaots  ota ooat taostosotoostssa toatotsooa  saooat ottatots st   oaotostats  ttot  at ttt soasatoaotso tto oooo ts soaossota ootatt ot  tsoaastostsa osattaa aaota saaoassato taaoo aastoa s sso asao aaat sotoattaoa so aoasaaa astasotatottsatttataao ataasttooooa t s  ot taosotoatttssoss ott stooo aaooto s satoottoottoaatsstatosttstt  sastt  ssotoats taats a stst  taasa ota  sasostoataaast
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 42 :
# Asoto ssoo toatoat t ttos os a oa a aaatssosotottaaatas s so s attaaoto saoa tsao stotoosstttastaaassss ootott stss ss  a ooaasososssastotsoaosoasot ooatstststtaataostsa tos  tsaastosoaot  tt   tasto aott  asattttsosaa ssosso ooto  aao tattts taosota os aatst  sa ttsoata tstttsostttas asssa atatoao otoaottstatoa ssatat  s ossoaoaaooootoattaatstaaass aatstsstottt saostt ttoa to tsa toaaosa stttsas o st oo oa o sao o ot aoatsot tsotaaoa atoaoaasosststass ttsatsaat sosssssasttstt   s tssstttootao  at  s staaata  oo o t astoatas tto osot t ta tsssttosooosa   sattatsto os sasoa so ssototoat oototooaaaao tsootossoosososot   t ot otasassstastsosstatss asstt ao tttsttoaasoo stotttoataotststtostsooost aaooasaatoostaao to  soooa aso a t oosa ooaaat  tst satooo  tsoaoaoasotoss aota o  a a otsot  atotto o ssasaosooo otoosssaooo sootsaasattastoats saa st tossaosaoas ooo otatot  aoooaas  totta o s  taa s  ost atoto o saoosaaatsossaoatssa aoasstaaoasatt a   staosta s sotootoostsasaoto  aoaoss sotaoatas asotsosttosaassaosat a
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 43 :
# A tatats o asaooas sa  s totoasota aaaasto oat os aatatt o st  osoststtsast asasso stt a a ts sos at ooootoo ot tots stasoas toos aossaosa tooat o a tssaaaoaottt oso  sotst    aass sa  taotasaaat ato tao aosaattoottsaso  atstta  ssa ssoat  attaosoooataaat o saaasot  otaoo tos tstat  oa  atataatttaas tsataottsooootattoo osoatt totostt tao s ttsaast oossst toao a ts ootooosat sttaost ost ootaassaaoaoo o t saoa osttoaat ot t ott ttosassssaasotatatstoaott ttos soats soaso    a ats s a otos sa so  oss sts taasts tattsst ststt a a a ooast a ssaas sa ttoa astsaoasoaastt tasot  t t taos oaaot  aotsaa  ttao attoastaa as t  asa totottttaot ttta  atasoaosaotot ttaatosotta soos a  aosoa ttata ttttoosoto oao  taatt  ootatt tosoas t to ssoaoa soasts  ta aoa ooo tasottotso sostasaosa aoooa tttstsaoss oostat ostssataaotootssaatta totoots tastaasa  ttssa o aao tatsott ssastoao  sasastot soos  tatatttsao s os tatatotto tata assasosssasootos oatootsota aos soatootso  oaaaoto osao stosota  ststsaaaoto  tsoa  sasooaat tsa ootsstto
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 44 :
# Aaatsst t   ot ottasts    a tt satoto so otatsoosas otoasostsaa ttoaatsoattott ts sato  stooatoaotso oaaosotaotaoas ts a  ssto sa ooo oost stssa ts os ooatts tsoatoott  aoaoa otoaatoasast tott tstsass taaotoso t oaao   s sttsos aa osooasataaso aa asosotaotostt stosaastosaatosttaataa  sss aaooa aot s atoasota tatastaattao  osato  assooassa  sttooatttas soat  sasta s oots too tttsosa o taaa  stoo ota  so oo  sstat tso  totot sa  stsaaoaatas  oo  tossatta oa  oot ossttaottosatt  aos attaa s aotsta t  t o otsoos  tsat a  sstaattsatsost ttssootoasotsaaos to tattoooato toatootaaas toot tsos taotatso tao otoaosassosatt s  t ta tots st   att  ttotaaaotto s oaa saos tat aasatoa o soss sas tosts  tsaoa aasotttasostaossoasostat aot tta oaaottt tssoss t  ootaasst aoaattoosos tatsttsoatoototsotota tastt tooas asaasosossoost oat stast ooa ooats oossstataa   tt tstaass tsoa astttss  otosatooosootsaosttaastt aaottts ssa sso  to saao at saoatoo oottaas ttaaoasst s  toaasssaat a ssoooosatsot st ooo aoottss  aaoa  tatatatassaaao
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 45 :
# Asooot oso so  otooa  aot aatto ataao a t osossa aoa  ao ooaa toassosaa os aos o assttssostt tt ott staosoostatsasso sooaototosotsoo aostt aaoasts assatttao ostastatoatso atatattt  ooattotttaaototastotasat ssaass as atsotossaaostosts otaot tooooo t tasassao so ttsosaatoatst atastaaasa at  stat ottoaasost t o oattoaato  a oas ttsooo  ossatssaatssoooto ttso ttoaoaatsasa t  ta at oasatstssss  otsoo toaottoaa oasotsa oa aaosot aasttt ooa  tsso soa ooasatssta aaaattaoo taoato s attttosotoassoaasasttoatoaossstos sttaotot atsott tso taosatto saoto  ao oasttsotatattaoaa aaatsato soa sostoo aosatao ststtstattt otaats assssoa ott atsatta a aao s osat tatas sast oasasatoaaooaoatso ostao s tasoo oaooaoaoaasstttaaoos oa at ota tat aa  ssa aoaat atsa to ottatoatasaos ttaao ta aoottottoossaso ao sasoasooaoso otsttstt  os  tttttotosstasts taatoaoass oo astsosasaat tooto ott atto so  tsstsatssost to aota  a aat attoss  asaa satosstoaa ao otta t at oooo sstaatasooao aatotsoatt a sas  stoaosstaoooaoaottoattoaaaoosoo aosaa tssoaa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 46 :
# Atsosatooaasaoaoasstst tsot tst oaat aasas st  s  aaast t sttataoas os a tsao atatttt aat  aott atostaoso aaattt as sto oassaaaao soo s  att t  tot aa  soao oo a t ootas asssaoasssoattt oasooa ss aaa a  t taatasottttaossotooataaatsta s soosssstt at att o sa oasostooostosooto t atataa sstsoao t asao osoatatottts tttotosoaaoo at tattotaoott  s  soo oso  osoo stsa  a   staaoa tssa ta ss ass aoasoto ssstt a sotoaoass aoottsooss   asaoattosattsaos  t asaota s tooa sota tsosoa aso a  ts ta  t sa sosasootas t soatssoao ssstaos t so s   aosa aoaso to aaa   a a  ststtaaaoa  toatattto o aatatssaatsaasattooaooo ooassaotsaaatsoo osto   taatotaattasotsoaa  sotataa sto sto aos  osta aata tst oso ataso saosatos aooot ost atto oa s taottosa ts st tsaattooottooto totos osttoso sata tatotaatststassa  tstasat  otoaosaoosao ta  ssoo sa    stooo ot aotaassosao ssast sssoaoaaa aasaaataoasost ao sssaatsao t stoootsosta ttootosoa ttttaoa tsoaa osaotaa tttoo tsatto staoosstoat t oooa  a a o sa ttaataatso o oaaaastots to tootsaa  taooa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 47 :
# Aa oaotsaaaasotoosaot  aootootst a aooa tasaotas attoaots ttotaotsttootos tast toooaaaotatoao a  sso ttstosooaaa ooao sta aas so  ttoatsootaasatsoatotsss o ttotoataosoaootsstsstoo a o tts sto saostooatsastaoas  t asss staoatoaao  ttot   ootao  aaoa ataoa  ott atoaos s tsoaosastsstatsatasasasootasatttsstooa asoo  a tt  at ata asta  a oo so oaa aa tat sas oaoasoststta aoottats ttt  s  staotsssoasaosa ts tao tootaaoooso s aoaosoooaosotootoa o toa ooatastt ttassotots attsooo satost  as ts oot asttasttaosso  sstosooaos toaoa ttt tttaaa sotaaattt aoootasoas  assattots at at ttoaaooss  sttstostost tas s ttaoaostt os ooaaasaooaoaotaas ostototstaat oasttttttaa otas oottso at oo sst tttsa aasa t aoss asotttosssatsoasstsat oasost tsttaooat toatos a staa atotsa t osoa aottososatotsttaa s a  ot oss oaooaa saoss   sssootsas  toatssos ttttst  s a oaataottooosasttsssaasoot ttt sto    attoaosoatsato  sotta aaooa aoosto tsoottastaaa  tta taoasaoosas ssts otsaatsootoattsaotstsaast atso aoaa toaoatto otaatsotsattto ssotsotas  oa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 48 :
# Astao ottot ootstaossss aotoaaoaattsostsasstatoaooasossotoss  asao  at  t ttta s ssssatt ataoosos  sa toaatt toatostt ttstaoatso otastossa  t o s ta otssaosa aso aaso so  t oaaaat  aa ot t s oo oa aaoatta   ttaaatt atst stssot sa  aoo   att  o o  aosasoooa a asosststtaoo satostt  o taoattsaaoaassstaaottt st so ssasosat ttost tstaoatsaaot  oot aotttt t o oaoaoa  aattota a ost a o s soss toossstot  asootst st tat t tsaa asa sotoassstta taosatattstooaaas  sos oaaoaoato aooasoottatosoaaaot ts o tt s aooa ta   tottototsoososa   at  a s soataaaaoo attt  tsot toattas to tosoa saassstoattttosaosasaotattaoot  oatoa tot  tasstataa ttot aaottasoao aooa aa so ssataao s oattaoaos aa a toaosa ttsaoaaosats  aaa ot s ooto stooaatoaa s  ss tossasss s  stot otssoo attososaoaoo  aaaasas otsatsoottsosaosostosttt stoaosos o at tto  aaottaostoats oatoa tas t tsaaaoatt atst stost aoass oot oas astooss os tssa o osttattaoasotst ta atoatttss ataaoa stsot saos st  s tooaoaasatata osaoottstaoaaaata aso to attt aooaos so ooootsao  sasaat
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 49 :
# A ss aa ott otsaaoassotsotoasots  t ttaasaost t   at t saaaot sstssta t o st  s o o oats asas sststtaooastsaoooot ostasosasta    o oo  aa tassssaot sos tttstt  ot a aos aas  otaao totto otootottoa sato  ootoaoasaaottttatts ao  oaoaoat  otoossost tt ttoa tssaoossotattoaoosoasoa o saatttoosso a aso otosssott tao o  s ttssts aoo s  sostsaaaao ta  atasaootoatttt s oaasots  toaooosos stoass tt   os atttstaaoosostao aottota tatato tsatataasttsasaa  tsta a totooa s a toto so oaat o ooto  ooa a st ss ssatts tssoa stoss o ttt tooaot tt sataattotao otts  t ossa o aotooaa  s oosaato tsos sooo aaoatt ooosotaataoooottt otott tttaoss oaa aoo taatsoto ao ttoooats o o sa tssttsott  tt a t  saoata tssaoaosa  t t s a oostattoto t ott s tat  atsasosto a  a  s  o  toaostasto ao tto atoatt  oss atoooatasas a ost otaotto soo otoos sootoott ost o  sssastoos atoossao st o  aooa oastoastotat aa  s  t ttsotosaossot tstsa tasa sattaa  ototaaa o a   taat  ooso ata t    aoosoaoa tasaosoaos aaatattotttaoo tat   taosssossatoasto tsaoss ttsa
# No. of Batches generated from given corpus = 1
# in except
# Model output for epoch 50 :
# Aosataoosst  a aaa  toaastat sas s  oos oosossoo sstosasa tso s saa toots attaaa  s ot ottoo oo soot soa a oa sstaataa otosstoootossstt a otssaosotsaottaass oossaostt ataas at otat   ts  asaaottttss s  att  tosssata atao ttatoatoos  s o aaossa tsttassootosoa to  toootsoaotottsot ttsastotsoatasaottao aaossos ottssaatoot osttsa tots ass sasto ssto s aoot aotsost oso ssststo tstttaa t  osoo aoattsastasaotsa ttsa  atsstto  s  a os oat taaooatottasoatoastt s st  o ots tto osoto asa asossttooa aoatasoo aaoatsas otoa  tosotoa otttts os t atatttsott  toa ta stsa t tsataasoo ooa aaaao osootos ataattstao osttattt s to tattosots so  taaatttttosaataoto  ssssoooastta t ttosaso  s ot ast tttott  tstoat s   ooooo aatt st stooooosatsssasota t  aaotsotstsooaat   sasaaotao tao ot sos o ataaoaat a ataot aao  a otot aaososasattssoao  oa saoa  sttsa satoaaoo o tosaassttoao tsatttta tsatoa s tsaaas tsa astaats oo saosstssoas ootttos  o   ssaoaatoo  ttota osas otattaas  aosossot toststsaot o ta  tatsosooasatoo   aottss at ttoso os o
